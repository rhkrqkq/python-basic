# %%
a = 10
a = 10 + 1
a
# Out:
# 11

# %%
b = 20
a
b
# Out:
# 20

# %%
print(a)
print(b)
# Out:
# 20
# 20

# %%
a = 20

# %%
a = 10        # 정수
b = 3.14      # 실수
c = "Python"  # 문자열
d = True      # 논리형

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
type(a)
# Out:
# int

# %%
x = 10
print(type(x))  # <class 'int'>

x = "안녕하세요"
print(type(x))  # <class 'str'>
# Out:
# <class 'int'>
# <class 'str'>
